# %% [markdown]
# ## Training the network
#
# In this notebook we take the generated images in the ``eneratedData`` folder and use them to train a neural network.
#
# ### What does it all do?
# We will walk througho the main steps so you can understand in basics steps in this notebook.
#
# ---
#
# First we need to import a couple of different libraries. You can see many of them contain the name ```troch```, this is the main machine learning library we will use.

# %%
from torch import nn
from torch import optim
import torch.nn as nn
import torch.nn.parallel
import torch.backends.cudnn as cudnn
import torch.nn.functional as F
from torchvision import datasets, transforms, models
import torchvision
import time
from sklearn.metrics import confusion_matrix

# %% [markdown]
# ## Define classes to train
#
# The less classes you have  the fewer data you need. So slecting just the right ammount of classes can be one way to reduce the ammount of processing and increase, potentially, the reliabilty.
#
# In the following section you can select which of the found classes should be included.

# %%
Type="TRAINING"
exec(open("../helperFunctions.py","rb").read())
# Out:
# Select classes to use for training:
# Checkbox(value=False, description='Dogs', indent=False)
# Checkbox(value=False, description='Cats', indent=False)

# %%
UsedClasses=[]
for k in widgetDict:
    if widgetDict[k].value==True:
        UsedClasses.append(k)
if(len(UsedClasses)<2):
    print("Something is wrong here. we need at least 2 classes!")

# %% [markdown]
# ## Loading data set
# If test set is not defined previously, this function pulls a test set from the training set using a 80/20%split

# %%
classes =  tuple(UsedClasses)

transform = transforms.Compose(
    [transforms.Resize(224),
    transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainSets=[]
testSets=[]

for cl in classes:   
    trainPath=os.path.join(SPECTRUM_IMAGES_ROOT,cl,'train')
    if os.path.isdir (trainPath):
        trainSets.append(SpectrumDataset(classes.index(cl),trainPath,transform))
    else:
        print('Coud not find path',trainPath);
    
    testPath=os.path.join(SPECTRUM_IMAGES_ROOT,cl,'test')
    if os.path.isdir (testPath):
        testSets.append(SpectrumDataset(classes.index(cl),testPath,transform))
    else:
        print('Coud not find path',testPath);


lowestItemCount=np.inf
classID=None
for i,train in enumerate(trainSets):
    if(lowestItemCount>len(train)):
        lowestItemCount=len(train)
        classID=i
        lowestItemCount=len(train)
for i in range(len(trainSets)):
    trainSets[i].ReduceSize(lowestItemCount)
    

TrainDataSet = torch.utils.data.ConcatDataset(trainSets)
TestDataSet = torch.utils.data.ConcatDataset(testSets)

trainloader = torch.utils.data.DataLoader(TrainDataSet, batch_size=16, shuffle=True)
testloader = torch.utils.data.DataLoader(TestDataSet, batch_size=16, shuffle=False)
# Out:
# ../GeneratedData/Dogs/train 2344
# ../GeneratedData/Dogs/test 1536
# ../GeneratedData/Cats/train 2901
# ../GeneratedData/Cats/test 1002

# %% [markdown]
# ## Preview sample training images

# %% [markdown]
# The following cell takes an entire training batch of images and displays them with their respective labels. Have a look and verify that indeed you see spectrograph images that look similar to what you saw earlier.

# %%
#Getting some random training images and showing them
dataiter = iter(trainloader)
images, labels = dataiter.next()
for i in range(trainloader.batch_size):
    imshow(images[i])
    print(classes[labels[i]])
# Out:
# Cats
# Cats
# Cats
# Cats
# Dogs
# Dogs
# Cats
# Cats
# Cats
# Cats
# Cats
# Dogs
# Cats
# Dogs
# Cats
# Cats

# %% [markdown]
# ## Specify use of Graphics Card (if there is one) and use ResNet

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = models.resnet18(pretrained=False)

# %% [markdown]
# ## Load pretrained model
# The model '../Models/MainModelUrban.pth' was trained on the UrbanSound dataset; other models could be specified instead.

# %%
ModelData = torch.load('../Models/MainModelUrban.pth',map_location='cpu')
model.load_state_dict(ModelData['model'])
# Out:
# <All keys matched successfully>

# %% [markdown]
# ## Cutting off the head
# In the following cell, the setting 'param.requires_grad = False' is **the** function that is telling the network to only retrain the last layer. If you set this parameter to True, the training will take much longer, but hopefully be better at predicting.

# %%
'''
For each parameter in the network we turn of training, 
by setting  .requires_grad  to `False`.

This makes sure that the computer will not try to adjust thos variables when "training".
'''
for param in model.parameters(): #
    param.requires_grad = False #... 
    
'''
'fc' stands for "fully connected" and it is the very last layer in the neural net.
We replace this layer with a new fully connected layer, that connects the 512 input neurons to neurons for our classes.
'''    
model.fc = nn.Linear(512, len(classes))

# %% [markdown]
# ## Move model to GPU (if there is a GPU)

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
train_epoch_losses=[]
test_epoch_losses=[]
epoch=0

# %% [markdown]
# ## Training the network

# %%
#Training the network on the training dataset
for i in range(5):  # loop over the dataset multiple (5) times 
    epoch+=1
    print("Starting epoch:",epoch)
    epochLoss=0.0
    t0 = time.time()
    model.train()
    for i, data in enumerate(trainloader, 0):
        #print("Running Batches",i)
        # get the inputs
        inputs, labels = data
        if device.type=='cuda':
            inputs, labels = inputs.to(device), labels.to(device)
        
        # zero the parameter gradients
        optimizer.zero_grad()
        if((i+i)%50==0):
            if(i>0):
                print('Processed images:',i*trainloader.batch_size,'. Running Timer @ {:.2f}sec.'.format(time.time()-t0))
        # forward + backward + optimize
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        epochLoss+=loss.item()
        
    
    model.eval()
    testLoss=0
    print("About to test the performance on the test set.")
    with torch.no_grad():
        for i, data in enumerate(testloader, 0):
            # get the inputs
            inputs, labels = data
            if device.type=='cuda':
                inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            testLoss+=loss.item()
            if(i%50==0):
                if(i>0):
                    print('Tested images:',i*testloader.batch_size,'. Running Timer @ {:.2f}sec.'.format(time.time()-t0))


    train_epoch_losses.append(epochLoss/len(trainloader))
    test_epoch_losses.append(testLoss/len(testloader))
    EpochLength = time.time()-t0
    print('{} train loss: {:.3f} and test loss: {:.3f}, and it took us: {:.2f} seconds.'.format (epoch + 1, epochLoss / len(trainloader),testLoss/len(testloader),EpochLength))  # DAVID CHanged it to 1000 from 2000 not sure if thats totally done
print('Finished Training')
# Out:
# Starting epoch: 1
# Processed images: 400 . Running Timer @ 63.19sec.
# Processed images: 800 . Running Timer @ 133.72sec.
# Processed images: 1200 . Running Timer @ 200.92sec.
# Processed images: 1600 . Running Timer @ 269.77sec.
# Processed images: 2000 . Running Timer @ 339.78sec.
# Processed images: 2400 . Running Timer @ 401.07sec.
# Processed images: 2800 . Running Timer @ 467.80sec.
# Processed images: 3200 . Running Timer @ 532.70sec.
# Processed images: 3600 . Running Timer @ 597.88sec.
# Processed images: 4000 . Running Timer @ 680.25sec.
# Processed images: 4400 . Running Timer @ 785.26sec.
# About to test the performance on the test set.
# Tested images: 800 . Running Timer @ 1002.12sec.
# Tested images: 1600 . Running Timer @ 1116.20sec.
# Tested images: 2400 . Running Timer @ 1215.38sec.
# 2 train loss: 0.536 and test loss: 0.450, and it took us: 1231.19 seconds.
# Starting epoch: 2
# Processed images: 400 . Running Timer @ 59.30sec.
# Processed images: 800 . Running Timer @ 120.22sec.
# Processed images: 1200 . Running Timer @ 184.94sec.
# Processed images: 1600 . Running Timer @ 241.72sec.
# Processed images: 2000 . Running Timer @ 298.36sec.
# Processed images: 2400 . Running Timer @ 354.64sec.
# Processed images: 2800 . Running Timer @ 412.22sec.
# Processed images: 3200 . Running Timer @ 469.43sec.
# Processed images: 3600 . Running Timer @ 531.11sec.
# Processed images: 4000 . Running Timer @ 598.28sec.
# Processed images: 4400 . Running Timer @ 656.83sec.
# About to test the performance on the test set.
# Tested images: 800 . Running Timer @ 794.78sec.
# Tested images: 1600 . Running Timer @ 895.56sec.
# Tested images: 2400 . Running Timer @ 989.04sec.
# 3 train loss: 0.459 and test loss: 0.414, and it took us: 1003.65 seconds.
# Starting epoch: 3
# Processed images: 400 . Running Timer @ 56.30sec.
# Processed images: 800 . Running Timer @ 109.48sec.
# Processed images: 1200 . Running Timer @ 162.47sec.
# Processed images: 1600 . Running Timer @ 217.20sec.
# Processed images: 2000 . Running Timer @ 270.78sec.
# Processed images: 2400 . Running Timer @ 325.39sec.
# Processed images: 2800 . Running Timer @ 383.05sec.
# Processed images: 3200 . Running Timer @ 438.24sec.
# Processed images: 3600 . Running Timer @ 492.28sec.
# Processed images: 4000 . Running Timer @ 546.01sec.
# Processed images: 4400 . Running Timer @ 600.76sec.
# About to test the performance on the test set.
# Tested images: 800 . Running Timer @ 732.73sec.
# Tested images: 1600 . Running Timer @ 822.87sec.
# Tested images: 2400 . Running Timer @ 912.11sec.
# 4 train loss: 0.406 and test loss: 0.418, and it took us: 925.61 seconds.
# Starting epoch: 4
# Processed images: 400 . Running Timer @ 55.43sec.
# Processed images: 800 . Running Timer @ 109.93sec.
# Processed images: 1200 . Running Timer @ 165.31sec.
# Processed images: 1600 . Running Timer @ 219.52sec.
# Processed images: 2000 . Running Timer @ 274.27sec.
# Processed images: 2400 . Running Timer @ 330.13sec.
# Processed images: 2800 . Running Timer @ 387.68sec.
# Processed images: 3200 . Running Timer @ 447.63sec.
# Processed images: 3600 . Running Timer @ 509.69sec.
# Processed images: 4000 . Running Timer @ 570.70sec.
# Processed images: 4400 . Running Timer @ 629.62sec.
# About to test the performance on the test set.
# Tested images: 800 . Running Timer @ 767.15sec.
# Tested images: 1600 . Running Timer @ 858.52sec.
# Tested images: 2400 . Running Timer @ 963.16sec.
# 5 train loss: 0.391 and test loss: 0.341, and it took us: 977.78 seconds.
# Starting epoch: 5
# Processed images: 400 . Running Timer @ 56.42sec.
# Processed images: 800 . Running Timer @ 112.36sec.
# Processed images: 1200 . Running Timer @ 168.19sec.
# Processed images: 1600 . Running Timer @ 226.06sec.
# Processed images: 2000 . Running Timer @ 284.12sec.
# Processed images: 2400 . Running Timer @ 340.25sec.
# Processed images: 2800 . Running Timer @ 398.16sec.
# Processed images: 3200 . Running Timer @ 455.07sec.
# Processed images: 3600 . Running Timer @ 512.80sec.
# Processed images: 4000 . Running Timer @ 576.18sec.
# Processed images: 4400 . Running Timer @ 637.97sec.
# About to test the performance on the test set.
# Tested images: 800 . Running Timer @ 780.50sec.
# Tested images: 1600 . Running Timer @ 878.21sec.
# Tested images: 2400 . Running Timer @ 983.41sec.
# 6 train loss: 0.359 and test loss: 0.332, and it took us: 999.41 seconds.
# Finished Training

# %% [markdown]
# ## Post training analytics

# %% [markdown]
# After the training has finished, save information about the training

# %%
# saving the learnd model in file that can be loaded in for inference
torch.save({
    'model':model.state_dict(),
    'classes':classes,
    'resolution':224,
    'modelType':"resnet18" # <= If you try out different models make sure to change this too
},"../models/CatDogResNet.pth") # <=Edit file name here

# %% [markdown]
# Display how the traing and test loss progressed over successive epochs

# %%
#Displaying how the loss progresses over time.
plt.plot(train_epoch_losses, label='Training Loss',c='r')
plt.plot(test_epoch_losses, label='Test Loss',c='g')
plt.legend()
plt.show()

# %% [markdown]
# Show spectagrams, Predicted and Actual labels.

# %%
# Print predicted and acual labels for Spectragrams
model.eval()
dataiter = iter(testloader)
images, labels = dataiter.next()
images, labels = images.to(device), labels.to(device)
outputs = model(images)
_, predicted = torch.max(outputs, 1)
for i in range(trainloader.batch_size):
    imshow(images[i].cpu())
    print('GroundTruth: ',classes[labels[i]])
    print('Predicted: ',  classes[predicted[i]])
# Out:
# GroundTruth:  Dogs
# Predicted:  Dogs
# GroundTruth:  Dogs
# Predicted:  Dogs
# GroundTruth:  Dogs
# Predicted:  Cats
# GroundTruth:  Dogs
# Predicted:  Dogs
# GroundTruth:  Dogs
# Predicted:  Dogs
# GroundTruth:  Dogs
# Predicted:  Cats
# GroundTruth:  Dogs
# Predicted:  Dogs
# GroundTruth:  Dogs
# Predicted:  Cats
# GroundTruth:  Dogs
# Predicted:  Cats
# GroundTruth:  Dogs
# Predicted:  Dogs
# GroundTruth:  Dogs
# Predicted:  Dogs
# GroundTruth:  Dogs
# Predicted:  Cats
# GroundTruth:  Dogs
# Predicted:  Cats
# GroundTruth:  Dogs
# Predicted:  Dogs
# GroundTruth:  Dogs
# Predicted:  Dogs
# GroundTruth:  Dogs
# Predicted:  Dogs

# %% [markdown]
# Print accuracy of test predictions for each label

# %%
# Network analytics
class_correct = list(0. for i in range(len(classes)))
class_total = list(0. for i in range(len(classes)))
model.eval()
allLabels=[]
allPrediction=[]
with torch.no_grad():
    for data in testloader:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        if (c.dim()==0):
            continue
        for i in range(testloader.batch_size):
            if(len(labels)<=i):
                continue;
            label = labels[i]
            allLabels.append(labels[i].to('cpu').numpy())
            allPrediction.append(predicted[i].to('cpu').numpy())
            #print (c.shape)
            if(testloader.batch_size>1):

                class_correct[label] += c[i].item()
            else:
                class_correct[label] += c.item()
            class_total[label] += 1

print(confusion_matrix(allLabels, allPrediction))
for i in range(len(classes)):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# [[1302  234]
#  [ 125  877]]
# Accuracy of  Dogs : 84 %
# Accuracy of  Cats : 87 %

# %% [markdown]
# 5 Epoch:
# [[2126 1362]
#  [ 426 4373]]
# Accuracy of  Dogs : 60 %
# Accuracy of  Cats : 91 %
